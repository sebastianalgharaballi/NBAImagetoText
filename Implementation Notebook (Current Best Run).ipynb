# %%
from get_loader import Vocabulary, NBADataset, MyCollate, get_loader
from model import EncoderCNN, DecoderRNN, CNNtoRNN
from utils import print_examples, save_checkpoint, load_checkpoint
from train import train

# %%
train()
# Out:
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: donovan george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: damian paul anthony lillard . paul anthony durant <PAD> . nikola giannis donovan nikola donovan george anthony james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: giannis donovan embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: lebron giannis donovan nikola tatum james james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: giannis donovan embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: kawhi kawhi kawhi kawhi damian jayson james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: kawhi kawhi kawhi kawhi kawhi damian jayson james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: giannis donovan embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: giannis donovan embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis embiid embiid giannis
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: james devin james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george james george anthony james jokic devin james george
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> paul george . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> paul george . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> paul george . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> paul george . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> paul george . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> paul george . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> paul george . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> paul george . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> paul george . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> paul george . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> paul george . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> kevin durant . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> kevin durant . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kevin durant . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> kevin durant . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> kevin durant . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> kevin durant . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> kevin durant . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> kevin durant . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> kevin durant . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> kevin durant . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> kevin durant . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> kevin durant . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> kevin durant . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> kevin durant . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> anthony davis . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> anthony davis . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> anthony davis . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> anthony davis . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> anthony davis . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> anthony davis . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> anthony davis . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> anthony davis . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> anthony davis . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> anthony davis . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> anthony davis . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> anthony davis . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> anthony davis . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> anthony davis . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> anthony davis . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> anthony davis . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> anthony davis . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> anthony davis . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> anthony davis . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> anthony davis . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> anthony davis . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> anthony davis . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> anthony davis . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> anthony davis . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> anthony davis . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> anthony davis . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> anthony davis . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> anthony davis . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> anthony davis . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> anthony davis . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> anthony davis . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> anthony davis . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> anthony davis . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> anthony davis . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> anthony davis . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> anthony davis . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> devin booker . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> devin booker . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> devin booker . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> devin booker . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> devin booker . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> devin booker . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> devin booker . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> devin booker . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> devin booker . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> devin booker . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> devin booker . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> devin booker . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> paul george . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> paul george . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> paul george . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> paul george . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> paul george . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> paul george . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> paul george . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> paul george . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> paul george . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> paul george . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> paul george . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> paul george . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> paul george . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> paul george . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> paul george . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> paul george . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> paul george . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> joel embiid . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> paul george . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> paul george . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> paul george . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> paul george . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> paul george . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> lebron james . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> lebron james . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> lebron james . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> lebron james . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> lebron james . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> paul george . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> lebron james . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> lebron james . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> paul george . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> lebron james . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> paul george . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> kevin durant . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kevin durant . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> joel embiid . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> kevin durant . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> luka doncic . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> kevin durant . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> luka doncic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> luka doncic . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> paul george . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> luka doncic . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> luka doncic . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> luka doncic . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> devin booker . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> ja morant . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> devin booker . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> ja morant . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> devin booker . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> devin booker . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> devin booker . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> devin booker . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> devin booker . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> kevin durant . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> joel embiid . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> joel embiid . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> lebron james . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kevin durant . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> stephen curry . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> stephen curry . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> joel embiid . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> lebron james . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> joel embiid . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> luka doncic . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> lebron james . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> stephen curry . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> paul george . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> devin booker . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> anthony davis . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> lebron james . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kevin durant . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> devin booker . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> damian lillard . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> damian lillard . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> kevin durant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> devin booker . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> joel embiid . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> kevin durant . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> damian lillard . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> anthony davis . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> paul george . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> ja morant . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> ja morant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> lebron james . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> lebron james . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> lebron james . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> devin booker . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> anthony davis . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> ja morant . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> paul george . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> anthony davis . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> joel embiid . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> stephen curry . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> joel embiid . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> ja morant . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> lebron james . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> ja morant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> ja morant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> ja morant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> luka doncic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> kawhi leonard . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> ja morant . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# ...
# Example 10 OUTPUT: <SOS> kevin durant . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> paul george . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> anthony davis . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> joel embiid . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> kevin durant . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> ja morant . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> damian lillard . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> kevin durant . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> luka doncic . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> kevin durant . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> damian lillard . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
# Example 1 CORRECT: Anthony Davis
# Example 1 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 2 CORRECT: Damian Lillard
# Example 2 OUTPUT: <SOS> damian lillard . <EOS>
# Example 3 CORRECT: Devin Booker
# Example 3 OUTPUT: <SOS> devin booker . <EOS>
# Example 4 CORRECT: Donovan Mitchell
# Example 4 OUTPUT: <SOS> donovan mitchell . <EOS>
# Example 5 CORRECT: Giannis Antetokounmpo
# Example 5 OUTPUT: <SOS> giannis antetokounmpo . <EOS>
# Example 6 CORRECT: Ja Morant
# Example 6 OUTPUT: <SOS> devin booker . <EOS>
# Example 7 CORRECT: Jayson Tatum
# Example 7 OUTPUT: <SOS> jayson tatum . <EOS>
# Example 8 CORRECT: Joel Embiid
# Example 8 OUTPUT: <SOS> joel embiid . <EOS>
# Example 9 CORRECT: Kawhi Leonard
# Example 9 OUTPUT: <SOS> joel embiid . <EOS>
# Example 10 CORRECT: Kevin Durant
# Example 10 OUTPUT: <SOS> stephen curry . <EOS>
# Example 11 CORRECT: LeBron James
# Example 11 OUTPUT: <SOS> lebron james . <EOS>
# Example 12 CORRECT: Luka Doncic
# Example 12 OUTPUT: <SOS> luka doncic . <EOS>
# Example 13 CORRECT: Nikola Jokic
# Example 13 OUTPUT: <SOS> nikola jokic . <EOS>
# Example 14 CORRECT: Paul George
# Example 14 OUTPUT: <SOS> paul george . <EOS>
# Example 15 CORRECT: Stephen Curry
# Example 15 OUTPUT: <SOS> stephen curry . <EOS>
